# %%
# Define paths
raw_path = "/FileStore/raw/material_master"
bronze_table_path = "/delta/bronze/material_master"
silver_table_path = "/delta/silver/material_master"
bronze_checkpoint = "/chk/bronze/material_master"
silver_checkpoint = "/chk/silver/material_master"

# Create directories (idempotent)
dbutils.fs.mkdirs(raw_path)
dbutils.fs.mkdirs("/delta/bronze")
dbutils.fs.mkdirs("/delta/silver")
dbutils.fs.mkdirs("/chk/bronze")
dbutils.fs.mkdirs("/chk/silver")

print("Created/verified:")
for p in [raw_path, bronze_table_path, silver_table_path, bronze_checkpoint, silver_checkpoint]:
    print(" -", p)
